# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %matplotlib inline

# %%
teis_df = pd.read_excel (r'C:\Users\jubs1\Documents\NSS\python\projects\teis_project-ursula\data\TEIS Referral Data for NSS Compiled Monthly.xlsx')
teis_df.to_csv (r'C:\Users\jubs1\Documents\NSS\python\projects\teis_project-ursula\data\TEIS Referral Data for NSS Compiled Monthly.xlsx', index = None, header=True)

# %%
teis_df
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339 2014-08-09      Blount  Transitional   Eligibility
# 1       FT    404085 2013-07-31      Unicoi       At-Risk  Notification
# 2       FT    403623 2016-02-05    Sullivan  Transitional   Eligibility
# 3       FT    404157 2015-12-06    Sullivan  Transitional          IFSP
# 4       FT    404154 2015-04-18     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 113252  UC    528534 2022-03-13      Sumner   Competitive          IFSP
# 113253  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
# 113254  UC    528253 2020-09-12      Sumner   Competitive          IFSP
# 113255  UC    528535 2022-02-08       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification/ Referral Date  \
# ...

# %%
teis_df = teis_df.rename(columns = {'Child ID' : 'child id', 'Fiscal Year.1': 'fiscal_year1', 'Notification/ Referral Date': 'referral_date', 'Country SES': 'county_ses', 'Referral Source Type Name': 'referral_source', 'Initial Eligibility Date': 'success_date' })
teis_df
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 0       ET    403339 2014-08-09      Blount  Transitional   Eligibility
# 1       FT    404085 2013-07-31      Unicoi       At-Risk  Notification
# 2       FT    403623 2016-02-05    Sullivan  Transitional   Eligibility
# 3       FT    404157 2015-12-06    Sullivan  Transitional          IFSP
# 4       FT    404154 2015-04-18     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 113252  UC    528534 2022-03-13      Sumner   Competitive          IFSP
# 113253  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
# 113254  UC    528253 2020-09-12      Sumner   Competitive          IFSP
# 113255  UC    528535 2022-02-08       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator referral_date Parent Consent Date  \
# ...

# %%
teis_df.duplicated(subset=['child id']).sum()
# Out:
# 18306

# %%
teis_df.sort_values(by = 'child id', ascending = True)
teis_df
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 0       ET    403339 2014-08-09      Blount  Transitional   Eligibility
# 1       FT    404085 2013-07-31      Unicoi       At-Risk  Notification
# 2       FT    403623 2016-02-05    Sullivan  Transitional   Eligibility
# 3       FT    404157 2015-12-06    Sullivan  Transitional          IFSP
# 4       FT    404154 2015-04-18     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 113252  UC    528534 2022-03-13      Sumner   Competitive          IFSP
# 113253  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
# 113254  UC    528253 2020-09-12      Sumner   Competitive          IFSP
# 113255  UC    528535 2022-02-08       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator referral_date Parent Consent Date  \
# ...

# %%
dups_df = teis_df.loc[teis_df.duplicated(subset='child id', keep=False)]
dups_df
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 2       FT    403623 2016-02-05    Sullivan  Transitional   Eligibility
# 6       GN    404087 2014-10-29    Davidson   Competitive  Notification
# 7       GN    402274 2015-12-10  Montgomery  Transitional   Eligibility
# 11      MD    404074 2016-05-23      Shelby  Transitional  Notification
# 14      MD    404081 2016-04-23      Shelby  Transitional  Notification
# ...     ..       ...        ...         ...           ...           ...
# 113225  UC    508343 2021-06-14      Putnam  Transitional   Eligibility
# 113235  UC    512956 2019-10-17      Sumner   Competitive   Eligibility
# 113241  UC    497416 2021-01-08      Warren       At-Risk  Notification
# 113246  UC    527351 2021-07-08      Sumner   Competitive    Evaluation
# 113248  UC    516784 2020-09-01      Warren       At-Risk  Notification
#
#        Active Service Coordinator referral_date Parent Consent Date  ...  \
# ...

# %%
dups_df.sort_values(by = "child id")
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 8326    ET    360966 2014-01-18      Monroe       At-Risk  Notification
# 6007    ET    360966 2014-01-18      Monroe       At-Risk  Notification
# 5441    ET    361021 2014-02-17    Anderson  Transitional  Notification
# 6658    ET    361021 2014-02-17    Anderson  Transitional          IFSP
# 5189    GN    361038 2013-12-25      Wilson   Competitive   Eligibility
# ...     ..       ...        ...         ...           ...           ...
# 111573  ET    527636 2020-05-01      Blount  Transitional   Eligibility
# 110585  MD    527691 2021-12-23      Shelby  Transitional  Notification
# 112414  MD    527691 2021-12-23      Shelby  Transitional  Notification
# 111752  FT    527751 2021-10-23    Sullivan  Transitional  Notification
# 109913  FT    527751 2021-10-23    Sullivan  Transitional  Notification
#
#        Active       Service Coordinator referral_date Parent Consent Date  \
# ...

# %%
dupscount_df = dups_df.loc[dups_df.duplicated(subset='child id', keep='first')]
dupscount_df
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 1739    GN    404546 2015-06-28    Davidson   Competitive          IFSP
# 1751    MD    404524 2014-01-09      Shelby  Transitional    Evaluation
# 1775    ET    404319 2016-04-17    Anderson  Transitional   Eligibility
# 1819    SC    404136 2016-03-10  Rutherford   Competitive          IFSP
# 1836    ET    392203 2014-10-01       Roane  Transitional   Eligibility
# ...     ..       ...        ...         ...           ...           ...
# 113225  UC    508343 2021-06-14      Putnam  Transitional   Eligibility
# 113235  UC    512956 2019-10-17      Sumner   Competitive   Eligibility
# 113241  UC    497416 2021-01-08      Warren       At-Risk  Notification
# 113246  UC    527351 2021-07-08      Sumner   Competitive    Evaluation
# 113248  UC    516784 2020-09-01      Warren       At-Risk  Notification
#
#        Active   Service Coordinator referral_date Parent Consent Date  ...  \
# ...

# %%
dupscount_df.sort_values(by = "child id")
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 8326    ET    360966 2014-01-18      Monroe       At-Risk  Notification
# 6658    ET    361021 2014-02-17    Anderson  Transitional          IFSP
# 5189    GN    361038 2013-12-25      Wilson   Competitive   Eligibility
# 5446    ET    361040 2014-01-22       Roane  Transitional          IFSP
# 9302    SC    363098 2014-04-07     Bedford  Transitional          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113189  UC    527583 2019-09-17      Sumner   Competitive    Evaluation
# 111618  ET    527603 2021-07-08       Union       At-Risk   Eligibility
# 111573  ET    527636 2020-05-01      Blount  Transitional   Eligibility
# 112414  MD    527691 2021-12-23      Shelby  Transitional  Notification
# 111752  FT    527751 2021-10-23    Sullivan  Transitional  Notification
#
#        Active       Service Coordinator referral_date Parent Consent Date  \
# ...

# %%
teiscount_df = teis_df.drop_duplicates(subset = ['child id'], keep = False)
teiscount_df
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 0       ET    403339 2014-08-09      Blount  Transitional   Eligibility
# 1       FT    404085 2013-07-31      Unicoi       At-Risk  Notification
# 3       FT    404157 2015-12-06    Sullivan  Transitional          IFSP
# 4       FT    404154 2015-04-18     Hawkins       At-Risk          IFSP
# 5       GN    401584 2016-03-27  Montgomery  Transitional   Eligibility
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 113252  UC    528534 2022-03-13      Sumner   Competitive          IFSP
# 113253  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
# 113254  UC    528253 2020-09-12      Sumner   Competitive          IFSP
# 113255  UC    528535 2022-02-08       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator referral_date Parent Consent Date  \
# ...

# %%
teiscount_df.sort_values(by = "child id")
# Out:
#        POE  child id        DOB County Name    County SES   Child Phase  \
# 8326    ET    360966 2014-01-18      Monroe       At-Risk  Notification
# 6007    ET    360966 2014-01-18      Monroe       At-Risk  Notification
# 5441    ET    361021 2014-02-17    Anderson  Transitional  Notification
# 6658    ET    361021 2014-02-17    Anderson  Transitional          IFSP
# 5189    GN    361038 2013-12-25      Wilson   Competitive   Eligibility
# ...     ..       ...        ...         ...           ...           ...
# 111573  ET    527636 2020-05-01      Blount  Transitional   Eligibility
# 110585  MD    527691 2021-12-23      Shelby  Transitional  Notification
# 112414  MD    527691 2021-12-23      Shelby  Transitional  Notification
# 111752  FT    527751 2021-10-23    Sullivan  Transitional  Notification
# 109913  FT    527751 2021-10-23    Sullivan  Transitional  Notification
#
#        Active       Service Coordinator referral_date Parent Consent Date  \
# ...

# %%
dupsRcount = dups_df.duplicated(subset=['child id']).sum()

# %%
dupsRcount
# Out:
# 18306

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9900/2117353666.py in <module>
# ----> 1 teisRcount_df = teiscount_df[teiscount_df.columns[0]].count()
#
# AttributeError: 'numpy.int64' object has no attribute 'columns'
