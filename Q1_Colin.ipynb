# %% [markdown]
# 1. What is the rate of re-referral? 16.25%
# How many children have multiple referrals (by year or by Point of Entry Office (POE))?
#
# "what % of the total number of referrals have duplicate child IDs?" = "what % of referrals are re-referrals?"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
clean_data = pd.read_csv('../../data/teis_final_data.csv')

# %%
clean_data.head()
# Out:
#    Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0    104085        2018-01-20   2017-2018                Jan      Middle
# 1    350065        2016-08-17   2016-2017                Aug      Middle
# 2    351755        2016-07-12   2016-2017                Jul     Western
# 3    353800        2016-09-14   2016-2017                Sep     Eastern
# 4    353805        2016-08-05   2016-2017                Aug      Middle
#
#    Fiscal Year.1   third_DOB  Late Referral  Qtr POE  ...  \
# 0         2017.0  2010-07-07            1.0  3.0  GN  ...
# 1         2016.0  2016-10-15            1.0  1.0  UC  ...
# 2         2016.0  2016-11-13            NaN  1.0  NW  ...
# 3         2016.0  2016-10-01            1.0  1.0  FT  ...
# 4         2016.0  2016-12-04            NaN  1.0  UC  ...
#
#             Service Coordinator Parent Consent Initial Eligibility  \
# 0                           NaN            NaN                 NaN
# ...

# %%
clean_data.shape
# Out:
# (115524, 25)

# %%
clean_data.columns
# Out:
# Index(['Child ID', 'Notification Date', 'Fiscal Year', 'Notification Month',
#        'Tenn Region', 'Fiscal Year.1', 'third_DOB', 'Late Referral', 'Qtr',
#        'POE', 'DOB', 'County Name', 'County SES', 'Child Phase', 'Active',
#        'Service Coordinator', 'Parent Consent', 'Initial Eligibility',
#        'Initial Eligibility Date', 'Initial IFSP Date', 'Latest IFSP',
#        'Exit Reason', 'Exit Date', 'Referral Source Type Name', 'Year'],
#       dtype='object')

# %%
#len(df.index)
#df.shape[0]
"what % of referrals are re-referrals?"

# %%
dups_only = clean_data[clean_data.duplicated(subset = ['Child ID'], keep='first')]

# %%
#this code takes the COUNT of duplicate child IDs (the # of rows in dups_df) and divides by the COUNT of all child IDs
#which gives you = "what % of the total number of referrals have duplicate child IDs?"
print(dups_only.shape[0])
print(clean_data.shape[0])
dups_only.shape[0] / clean_data.shape[0]
# Out:
# 18781
# 115524
# 0.162572279353208

# %%
#this shows you the unique children who have been referred more than once
dups_only.drop_duplicates(subset = ['Child ID'], keep = 'first')
# Out:
#         Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 25        360966        2017-01-12   2016-2017                Jan     Eastern
# 27        361021        2016-11-29   2016-2017                Nov     Eastern
# 29        361038        2016-08-26   2016-2017                Aug      Middle
# 31        361040        2016-10-28   2016-2017                Oct     Eastern
# 47        363098        2016-09-29   2016-2017                Sep      Middle
# ...          ...               ...         ...                ...         ...
# 113471    529200        2022-06-21         NaN                NaN         NaN
# 113561    529303        2022-06-17         NaN                NaN         NaN
# 113605    529365        2022-06-28         NaN                NaN         NaN
# 113657    529416        2022-05-26   2021-2022                May      Middle
# 113753    529524        2022-05-31   2021-2022                May     Eastern
#
# ...

# %% [markdown]
# How many children have multiple referrals (by year or by Point of Entry Office (POE))?

# %%
#referrals by year
clean_data['Child ID'].groupby(clean_data.Year).agg('count')
# Out:
# Year
# 2016     7904
# 2017    16936
# 2018    19119
# 2019    20307
# 2020    18975
# 2021    20878
# 2022    11405
# Name: Child ID, dtype: int64

# %%
#for some reason once I renamed Child ID to child_ID, it could no longer find it.
#compiled_monthly.rename(columns = {'Child ID':'child_ID', 'County Name':'county_name', 'County SES':'county_ses', 'Child Phase':'current_stage', 'Notification/ Referral Date': 'referral_date','Fiscal Year.1' : 'fiscal_year1', 'Referral Source Type Name': 'referral_source'})
# Out:
#        POE  boogers        DOB county_name    county_ses current_stage Active  \
# 0       ET   403339   8/9/2014      Blount  Transitional   Eligibility      A
# 1       FT   404085  7/31/2013      Unicoi       At-Risk  Notification      I
# 2       FT   403623   2/5/2016    Sullivan  Transitional   Eligibility      A
# 3       FT   404157  12/6/2015    Sullivan  Transitional          IFSP      A
# 4       FT   404154  4/18/2015     Hawkins       At-Risk          IFSP      A
# ...     ..      ...        ...         ...           ...           ...    ...
# 113251  UC   528759   4/7/2021      Sumner   Competitive    Evaluation      A
# 113252  UC   528534  3/13/2022      Sumner   Competitive          IFSP      A
# 113253  UC   528430   1/5/2022  Cumberland  Transitional   Eligibility      A
# 113254  UC   528253  9/12/2020      Sumner   Competitive          IFSP      A
# 113255  UC   528535   2/8/2022       Smith  Transitional    Evaluation      A
#
# ...

# %%
#iris_df[(iris_df.sepal_length > 5) & (iris_df.sepal_length < 7)]
compiled_monthly.duplicated(subset = ['child_ID'], keep=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 #iris_df[(iris_df.sepal_length > 5) & (iris_df.sepal_length < 7)]
# ----> 2 compiled_monthly.duplicated(subset = ['boogers'], keep=False)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6250, in DataFrame.duplicated(self, subset, keep)
#    6248 diff = Index(subset).difference(self.columns)
#    6249 if not diff.empty:
# -> 6250     raise KeyError(diff)
#    6252 vals = (col.values for name, col in self.items() if name in subset)
#    6253 labels, shape = map(list, zip(*map(f, vals)))
#
# KeyError: Index(['boogers'], dtype='object')

# %%
compiled_monthly.duplicated(subset='Child_ID')#.value_counts() #.groupby(['Animal']).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 compiled_monthly.duplicated(subset='Child_ID')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6250, in DataFrame.duplicated(self, subset, keep)
#    6248 diff = Index(subset).difference(self.columns)
#    6249 if not diff.empty:
# -> 6250     raise KeyError(diff)
#    6252 vals = (col.values for name, col in self.items() if name in subset)
#    6253 labels, shape = map(list, zip(*map(f, vals)))
#
# KeyError: Index(['Child_ID'], dtype='object')

# %%
#schools.level.value_counts()
multiple_referrals = compiled_monthly.Child_ID.value_counts()
multiple_referrals

# %%
multiple_referrals = multiple_referrals.to_frame()
type(multiple_referrals)

# %%
multiple_referrals = multiple_referrals.reset_index()

# %%
multiple_referrals = multiple_referrals.rename(columns = {'index':'Child_ID', 'Child_ID':'count'})
multiple_referrals

# %%
#schools.query('econ_disadv > 200')
multiple_referrals = multiple_referrals.query('count > 1')
multiple_referrals

# %%
compiled_monthly.columns
