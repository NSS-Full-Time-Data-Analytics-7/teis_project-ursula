# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pulled_7_1 = pd.read_csv('../../data/Referral_Data_Pulled_7-1-22.csv')

# %%
pulled_7_1.head()
# Out:
#   POE  Child ID         DOB County Name   County SES    Child Phase Active  \
# 0  ET    411812  12/14/2016      Blount  Transitional  Notification      I
# 1  ET    417398    4/6/2015        Knox  Transitional   Eligibility      I
# 2  ET    419400    3/4/2016       Roane  Transitional  Notification      I
# 3  ET    397571   5/11/2015        Knox  Transitional   Eligibility      I
# 4  ET    404648   9/23/2015        Knox  Transitional          IFSP      I
#
#   Service Coordinator Notification Date Parent Consent Date  \
# 0      Charity Decker        12/16/2016                 NaN
# 1     Jackie Campbell         4/24/2017            5/2/2017
# 2      Kelly Brackney          6/6/2017                 NaN
# 3        Wendy Burton         5/24/2017           6/13/2017
# 4         Sarah Scott         7/18/2016           7/28/2016
#
#   Referral Source Type Name Initial Eligibility Initial Eligibility Date  \
# 0                       DCS                 NaN                      NaN
# ...

# %%
pulled_7_1.shape
# Out:
# (96580, 17)

# %%
compiled_monthly = pd.read_csv('../../data/Referral_Data_Compiled_Monthly.csv')

# %%
compiled_monthly.head()
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339   8/9/2014      Blount  Transitional   Eligibility      A
# 1  FT    404085  7/31/2013      Unicoi       At-Risk  Notification      I
# 2  FT    403623   2/5/2016    Sullivan  Transitional   Eligibility      A
# 3  FT    404157  12/6/2015    Sullivan  Transitional          IFSP      A
# 4  FT    404154  4/18/2015     Hawkins       At-Risk          IFSP      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                    7/1/2016
# 1  Jennifer Terranera - 45 days                    7/1/2016
# 2                   Amy Talbert                    7/1/2016
# 3                Candice Cradic                    7/1/2016
# 4                Kathy Jeffries                    7/1/2016
#
#   Parent Consent Date  ... Service Coordinator Counter Fiscal Year.1  \
# 0              7/1/16  ...                           1          2016
# ...

# %%
compiled_monthly.shape
# Out:
# (113256, 34)

# %%
compiled_monthly.columns
# Out:
# Index(['POE', 'Child ID', 'DOB', 'County Name', 'County SES', 'Child Phase',
#        'Active', 'Service Coordinator', 'Notification/ Referral Date',
#        'Parent Consent Date', 'Referral Source Type Name',
#        'Initial Eligibility', 'Initial Eligibility Date', 'Initial IFSP Date',
#        'Latest IFSP Date', 'Exit Reason', 'Exit Date', 'Fiscal Year',
#        'Notification Month', 'Tenn Region', 'Referral Count',
#        'Evaluation Count', 'Eligibility Count', 'IFSP Count',
#        'Service Coordinator Counter', 'Fiscal Year.1', 'Child Count',
#        '2012 Child Count', '2013 Child Count', 'third DOB', 'Late Referral',
#        'Qtr', ' QTR ', 'Referral Source Category'],
#       dtype='object')

# %% [markdown]
# * What is the rate of re-referral? How many children have multiple referrals (by year or by Point of Entry Office (POE))?
# -15,287 children with mutiple referrals

# %%
compiled_monthly.rename(columns = {'Child ID':'Child_ID', 'County Name':'county_name', 'County SES':'county_ses', 'Child Phase':'current_stage', 'Notification/ Referral Date': 'referral_date','Fiscal Year.1' : 'fiscal_year1', 'Referral Source Type Name': 'referral_source'})
# Out:
#        POE  Child_ID        DOB county_name    county_ses current_stage  \
# 0       ET    403339   8/9/2014      Blount  Transitional   Eligibility
# 1       FT    404085  7/31/2013      Unicoi       At-Risk  Notification
# 2       FT    403623   2/5/2016    Sullivan  Transitional   Eligibility
# 3       FT    404157  12/6/2015    Sullivan  Transitional          IFSP
# 4       FT    404154  4/18/2015     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759   4/7/2021      Sumner   Competitive    Evaluation
# 113252  UC    528534  3/13/2022      Sumner   Competitive          IFSP
# 113253  UC    528430   1/5/2022  Cumberland  Transitional   Eligibility
# 113254  UC    528253  9/12/2020      Sumner   Competitive          IFSP
# 113255  UC    528535   2/8/2022       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator referral_date Parent Consent Date  \
# ...

# %%
#iris_df[(iris_df.sepal_length > 5) & (iris_df.sepal_length < 7)]
dups_df = compiled_monthly.duplicated(subset = 'Child_ID')
compiled_monthly[dups_df]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 #iris_df[(iris_df.sepal_length > 5) & (iris_df.sepal_length < 7)]
# ----> 2 dups_df = compiled_monthly.duplicated(subset = 'Child_ID')
#       3 compiled_monthly[dups_df]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6250, in DataFrame.duplicated(self, subset, keep)
#    6248 diff = Index(subset).difference(self.columns)
#    6249 if not diff.empty:
# -> 6250     raise KeyError(diff)
#    6252 vals = (col.values for name, col in self.items() if name in subset)
#    6253 labels, shape = map(list, zip(*map(f, vals)))
#
# KeyError: Index(['Child_ID'], dtype='object')

# %%
compiled_monthly.duplicated(subset='Child_ID')#.value_counts() #.groupby(['Animal']).mean()

# %%
#schools.level.value_counts()
multiple_referrals = compiled_monthly.Child_ID.value_counts()
multiple_referrals

# %%
multiple_referrals = multiple_referrals.to_frame()
type(multiple_referrals)

# %%
multiple_referrals = multiple_referrals.reset_index()

# %%
multiple_referrals = multiple_referrals.rename(columns = {'index':'Child_ID', 'Child_ID':'count'})
multiple_referrals

# %%
#schools.query('econ_disadv > 200')
multiple_referrals = multiple_referrals.query('count > 1')
multiple_referrals

# %%
compiled_monthly.columns
